# %%
import os
from src.solver import solve_captcha
model_path = "/Users/macmini/Desktop/CAPATCHA_solver/model/weights/best.pt"
directory = "/Users/macmini/Desktop/CAPATCHA_solver/data/test/images"

# %%
import os, sys

path = "/Users/macmini/Desktop/CAPATCHA_solver/data/test/images"
dir = os.listdir( path )

correct_labels=[]
predicted_labels=[]

for file in dir:
   correct_labels.append(os.path.splitext(file)[0])
   predicted_labels.append(solve_captcha(path+"/"+file,model_path))
# Out:
# 0: 640x640 2 0s, 1 5, 1 6, 1 7, 90.0ms
# Speed: 1.9ms preprocess, 90.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 0, 1 6, 1 8, 2 9s, 77.2ms
# Speed: 1.4ms preprocess, 77.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 3, 1 4, 1 7, 1 8, 1 9, 77.5ms
# Speed: 1.9ms preprocess, 77.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 0, 1 2, 1 4, 1 6, 1 9, 76.9ms
# Speed: 1.2ms preprocess, 76.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 2, 1 3, 1 6, 1 8, 1 9, 75.6ms
# Speed: 1.1ms preprocess, 75.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 0, 1 1, 2 5s, 1 9, 80.9ms
# Speed: 1.1ms preprocess, 80.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 0s, 2 1s, 1 2, 71.2ms
# Speed: 1.1ms preprocess, 71.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 0, 1 5, 2 7s, 1 9, 78.6ms
# Speed: 1.3ms preprocess, 78.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 4, 1 5, 2 6s, 1 9, 78.5ms
# Speed: 1.2ms preprocess, 78.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 0, 2 3s, 1 5, 1 7, 72.7ms
# Speed: 1.2ms preprocess, 72.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 3s, 1 6, 1 7, 1 8, 73.9ms
# Speed: 1.4ms preprocess, 73.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 0, 2 3s, 1 6, 1 9, 72.9ms
# Speed: 1.0ms preprocess, 72.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 1, 1 7, 3 8s, 67.1ms
# Speed: 1.2ms preprocess, 67.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 1, 1 2, 1 3, 1 5, 1 9, 78.0ms
# Speed: 1.0ms preprocess, 78.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 0, 1 1, 1 4, 1 5, 1 7, 72.6ms
# Speed: 1.1ms preprocess, 72.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 0, 2 3s, 1 6, 1 8, 76.6ms
# Speed: 1.3ms preprocess, 76.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 0, 1 1, 1 2, 2 4s, 62.5ms
# Speed: 0.9ms preprocess, 62.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 0, 1 1, 1 5, 2 8s, 74.2ms
# Speed: 1.2ms preprocess, 74.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 0, 1 3, 1 4, 1 5, 1 8, 57.3ms
# Speed: 1.3ms preprocess, 57.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 2s, 2 4s, 1 9, 74.0ms
# Speed: 1.8ms preprocess, 74.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 2, 1 6, 2 7s, 1 9, 65.0ms
# Speed: 1.1ms preprocess, 65.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 0, 2 4s, 1 8, 1 9, 78.2ms
# Speed: 1.0ms preprocess, 78.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 3s, 1 5, 2 7s, 69.0ms
# Speed: 1.0ms preprocess, 69.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 0, 1 1, 1 5, 1 7, 1 9, 91.3ms
# Speed: 1.1ms preprocess, 91.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 0s, 1 5, 1 6, 1 7, 69.4ms
# Speed: 1.1ms preprocess, 69.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 2s, 1 3, 1 5, 1 6, 74.3ms
# Speed: 1.4ms preprocess, 74.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 0, 1 2, 1 3, 1 4, 1 9, 67.8ms
# Speed: 1.4ms preprocess, 67.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 1, 1 3, 1 4, 1 6, 1 8, 86.3ms
# Speed: 1.1ms preprocess, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 0, 2 3s, 1 6, 1 9, 75.2ms
# Speed: 1.0ms preprocess, 75.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 0s, 1 4, 2 8s, 91.9ms
# Speed: 1.3ms preprocess, 91.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 0, 2 5s, 2 8s, 78.6ms
# Speed: 1.4ms preprocess, 78.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 1s, 1 6, 1 8, 1 9, 74.8ms
# Speed: 1.0ms preprocess, 74.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 0, 1 1, 1 3, 1 5, 1 8, 68.0ms
# Speed: 1.3ms preprocess, 68.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 1, 2 8s, 2 9s, 72.6ms
# Speed: 1.1ms preprocess, 72.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 1, 1 2, 3 7s, 67.1ms
# Speed: 1.2ms preprocess, 67.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 1, 2 7s, 2 9s, 76.5ms
# Speed: 1.4ms preprocess, 76.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 3, 1 5, 2 7s, 1 8, 69.0ms
# Speed: 1.0ms preprocess, 69.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 2s, 1 4, 1 7, 75.9ms
# Speed: 1.5ms preprocess, 75.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 0, 1 1, 1 2, 1 4, 1 7, 69.3ms
# Speed: 1.1ms preprocess, 69.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 0, 2 3s, 1 6, 1 9, 74.0ms
# Speed: 1.1ms preprocess, 74.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)

# %%
correct_count = 0

for i in range(len(correct_labels)):
    if correct_labels[i] == predicted_labels[i]: 
        correct_count += 1
    else:
        print(i)
        
accuracy = correct_count / len(correct_labels) 
print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0
